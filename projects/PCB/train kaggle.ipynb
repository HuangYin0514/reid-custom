# %%
cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !rm -rf reid-custom

# %%
# !git clone https://github.com/HuangYin0514/reid-custom.git
# Out:
# Cloning into 'reid-custom'...
# remote: Enumerating objects: 276, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 276 (delta 120), reused 241 (delta 85), pack-reused 0
# Receiving objects: 100% (276/276), 612.51 KiB | 10.04 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
# !ls
# Out:
# __notebook__.ipynb  reid-custom

# %%
# !pip install -e ./reid-custom/
# Out:
# Obtaining file:///kaggle/working/reid-custom
# ...
#   Running setup.py develop for torchreid
# ...

# %%
ls /kaggle/input/market1501/
# Out:
# Market-1501-v15.09.15/

# %%
# !pip install yacs

# %%
# !python3 /kaggle/working/reid-custom/projects/PCB/main.py \
--config-file /kaggle/working/reid-custom/projects/PCB/pcb_p6.yaml \
--root /kaggle/input/
# Out:
# /kaggle/working/reid-custom/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# Show configuration
# adam:
#   beta1: 0.9
#   beta2: 0.999
# cuhk03:
#   classic_split: False
#   labeled_images: False
#   use_metric_cuhk03: False
# data:
#   combineall: True
#   height: 384
#   norm_mean: [0.485, 0.456, 0.406]
#   norm_std: [0.229, 0.224, 0.225]
#   root: /kaggle/input/
#   save_dir: log/pcb_p6_save
#   sources: ['market1501']
#   split_id: 0
#   targets: ['market1501']
#   transforms: ['random_flip']
#   type: image
#   width: 128
#   workers: 4
# loss:
#   name: softmax
#   softmax:
#     label_smooth: True
#   triplet:
#     margin: 0.3
#     weight_t: 1.0
#     weight_x: 0.0
# market1501:
#   use_500k_distractors: False
# model:
#   load_weights:
#   name: PCB_p6
#   num_stripes: 6
#   pretrained: False
#   resume:
# ...

# %%
! tar zcf ./logs.tar ./log/

# %%
# !rm -rf reid*  log/*
