# %%
cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !rm -rf reid-custom
# !git clone https://github.com/HuangYin0514/reid-custom.git
# Out:
# Cloning into 'reid-custom'...
# remote: Enumerating objects: 348, done.
# remote: Counting objects: 100% (348/348), done.
# remote: Compressing objects: 100% (243/243), done.
# remote: Total 1012 (delta 231), reused 217 (delta 104), pack-reused 664
# Receiving objects: 100% (1012/1012), 1.20 MiB | 1.33 MiB/s, done.
# Resolving deltas: 100% (610/610), done.

# %%
cd ./reid-custom/
# Out:
# /kaggle/working/reid-custom

# %%
# !python main.py \
    --experiment=pcb_rga \
    --dataset_path=/kaggle/input/market1501/Market-1501-v15.09.15 \
    --batch_size=64 \
    --test_every=20 \
    --epoch=60
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 200MB/s]
# Use_Spatial_Att: True;	Use_Channel_Att: False.
# 2020-07-11 18:24:00 ----------
# 2020-07-11 18:24:00 {'nThread': 4, 'nGPU': 1, 'save_path': './experiments', 'experiment': 'pcb_rga', 'dataset': 'Market1501', 'dataset_path': '/kaggle/input/market1501/Market-1501-v15.09.15', 'height': 384, 'width': 128, 'batch_size': 64, 'stripes': 6, 'epochs': 60, 'test_every': 20, 'fixbase_epoch': 0, 'lr': 0.1, 'decay_every': 20, 'gamma': 0.1}
# 2020-07-11 18:24:00 Epoch 1/60
# ...

# %%
# !python test.py \
    --experiment=pcb_rga \
    --dataset=Occluded_REID \
    --dataset_path=/kaggle/input/occluded-reid \
    --checkpoint=experiments/Market1501 \
    --batch_size=512
# Out:
# Use_Spatial_Att: True;	Use_Channel_Att: False.
# 2020-07-11 20:10:34 {'experiment': 'pcb_rga', 'save_path': './experiments', 'which_epoch': 'final', 'checkpoint': 'experiments/Market1501', 'dataset': 'Occluded_REID', 'dataset_path': '/kaggle/input/occluded-reid', 'height': 384, 'width': 128, 'batch_size': 512, 'share_conv': False}
# Extracting features from query set ...
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Done, obtained 1000-by-1536 matrix
# Extracting features from gallery set ...
# Done, obtained 1000-by-1536 matrix
# Computing distance matrix with metric=cosine ...
# Computing CMC and mAP ...
# 2020-07-11 20:10:46 Testing: top1:0.6020 top5:0.7420 top10:0.8100 mAP:0.5388

# %%
from PIL import Image
import numpy as np
 
I = Image.open('experiments/Market1501/train_log.jpg') 
I.show()

# %%
# !zip -r ../experiments.zip ./experiments/*
# !rm -rf   experiments*  project_result*
